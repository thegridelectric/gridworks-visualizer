# %%
import dotenv
import pendulum
from sqlalchemy import asc, cast
from sqlalchemy import create_engine, select, BigInteger, MetaData, Table
from sqlalchemy.orm import sessionmaker
from config import Settings
from models import MessageSql
from gridflo.asl.types import FloParamsHouse0
from gridflo.dijkstra_types import DNode, DEdge
from gridflo import Flo, DGraphVisualizer, DNodeVisualizer
from gridflo.asl.types import WinterOakSupergraphParams
from gridflo.supergraph_generator import WinterOakSupergraphParams
from gridflo.dijkstra_types import DNode
import gc
import os
import shutil
from reportlab.lib.pagesizes import A4
from reportlab.lib.units import inch
from reportlab.pdfgen import canvas
from PIL import Image

print("\nWelcome to the FLO report generator!\n")
house_alias = input("Enter house alias: ")
if not house_alias:
    print("House alias is required")
    exit()

now = pendulum.now(tz='America/New_York')
yesterday_8pm = now.subtract(days=1).set(hour=20, minute=0, second=0, microsecond=0)

start_input = input("Enter start year, month, day, hour (default: yesterday 8pm): ")
if start_input and len(start_input.split(',')) == 4:
    START_YEAR, START_MONTH, START_DAY, START_HOUR = start_input.split(',')
    START_YEAR, START_MONTH, START_DAY, START_HOUR = int(START_YEAR), int(START_MONTH), int(START_DAY), int(START_HOUR)
else:
    START_YEAR, START_MONTH, START_DAY, START_HOUR = yesterday_8pm.year, yesterday_8pm.month, yesterday_8pm.day, yesterday_8pm.hour

end_input = input("Enter end year, month, day, hour (default: now): ")
if end_input and len(end_input.split(',')) == 4:
    END_YEAR, END_MONTH, END_DAY, END_HOUR = end_input.split(',')
    END_YEAR, END_MONTH, END_DAY, END_HOUR = int(END_YEAR), int(END_MONTH), int(END_DAY), int(END_HOUR)
else:
    END_YEAR, END_MONTH, END_DAY, END_HOUR = now.year, now.month, now.day, now.hour

start_time = pendulum.datetime(START_YEAR, START_MONTH, START_DAY, START_HOUR, tz='America/New_York')
end_time = pendulum.datetime(END_YEAR, END_MONTH, END_DAY, END_HOUR, tz='America/New_York')

# TEMPORARY
# house_alias = "oak"
# start_time = pendulum.datetime(2026, 1, 20, 20, tz='America/New_York')
# end_time = pendulum.datetime(2026, 1, 20, 22, tz='America/New_York')

start_ms = start_time.timestamp()*1000
end_ms = end_time.timestamp()*1000
print(f"Generating report for {house_alias} from {start_time} to {end_time}\n")

# ---------------------------------------------------
# Part 1: Find FLO params messages
# ---------------------------------------------------

stmt = select(MessageSql).filter(
    MessageSql.message_type_name == "flo.params.house0",
    MessageSql.from_alias == f"hw1.isone.me.versant.keene.{house_alias}",
    MessageSql.message_persisted_ms <= cast(int(end_ms+10*60*1000), BigInteger),
    MessageSql.message_persisted_ms >= cast(int(start_ms-10*60*1000), BigInteger),
).order_by(asc(MessageSql.message_persisted_ms))

settings = Settings(_env_file=dotenv.find_dotenv())
engine = create_engine(settings.db_url_no_async.get_secret_value())
Session = sessionmaker(bind=engine)
session = Session()
result = session.execute(stmt)
messages = result.scalars().all()

flo_params_messages = []
for m in messages:
    if pendulum.from_timestamp(m.message_persisted_ms/1000, tz='America/New_York').minute == 57:
        print(f"Adding message from {m.from_alias} at {pendulum.from_timestamp(m.message_persisted_ms/1000, tz='America/New_York')}")
        flo_params_messages.append(m)

print(f"Found {len(messages)} messages and {len(flo_params_messages)} of them at minute 57\n")

session.close()
engine.dispose()

# ---------------------------------------------------
# Part 2: Find hourly data: hp_elec_in, hp_heat_out
# ---------------------------------------------------
# Use backoffice DB (same as get_electricity_use in visualizer_api.py)
gbo_engine = create_engine(settings.gbo_db_url_no_async.get_secret_value())
hourly_electricity = Table('hourly_electricity', MetaData(), autoload_with=gbo_engine)
GboSession = sessionmaker(bind=gbo_engine)
gbo_session = GboSession()
stmt_hourly = select(hourly_electricity).where(
    hourly_electricity.c.short_alias == house_alias,
    hourly_electricity.c.hour_start_s >= int(start_ms // 1000),
    hourly_electricity.c.hour_start_s <= int(end_ms // 1000),
).order_by(asc(hourly_electricity.c.hour_start_s))
hourly_records = gbo_session.execute(stmt_hourly).all()
# Build lists: one row per hour (hp_elec_in may be stored as hp_kwh_el in DB)
hourly_hour_start_s = []
hourly_hp_elec_in = []
hourly_hp_heat_out = []
for rec in hourly_records:
    hourly_hour_start_s.append(rec.hour_start_s)
    hourly_hp_elec_in.append(getattr(rec, 'hp_elec_in', getattr(rec, 'hp_kwh_el', 0)))
    hourly_hp_heat_out.append(getattr(rec, 'hp_kwh_th', getattr(rec, 'hp_heat_out', 0)))
print(f"Found {len(hourly_records)} hourly records for {house_alias} (hp_elec_in, hp_heat_out)")
gbo_session.close()
gbo_engine.dispose()

# ---------------------------------------------------
# Part 3: Generate plots in plots/ directory
# ---------------------------------------------------

if os.path.exists('plots'):
    shutil.rmtree('plots')
os.makedirs('plots', exist_ok=True)

true_init_energy, true_final_energy = [0]*len(flo_params_messages), [0]*len(flo_params_messages)
heat_to_store_expected = []
heat_from_hp_expected = []
true_initial_states, true_final_states = [None]*len(flo_params_messages), [None]*len(flo_params_messages)

for i, flo_params_msg in enumerate(flo_params_messages):
    flo_params = FloParamsHouse0(**flo_params_msg.payload)
    g = Flo(flo_params.to_bytes())
    g.solve_dijkstra()
    g.generate_recommendation(flo_params.to_bytes())
    v = DGraphVisualizer(g)
    v.plot(show=False,save_as=f'plots/flo{i+1}_graph.png')
    v.plot_pq_pairs(save_as=f'plots/flo{i+1}_pq_pairs.png')
    initial_node_edge: DEdge = [e for e in g.bid_edges[g.initial_node] if e.head == g.initial_node.next_node][0]
    hp_heat_out_expected = initial_node_edge.hp_heat_out
    heat_to_store_expected.append(hp_heat_out_expected - initial_node_edge.load_and_losses)
    heat_from_hp_expected.append(hp_heat_out_expected)

    winter_oak_supergraph_params = WinterOakSupergraphParams(
        num_layers=flo_params.num_layers,
        storage_volume_gallons=flo_params.storage_volume_gallons,
        hp_max_elec_kw=flo_params.hp_max_elec_kw,
        cop_intercept=flo_params.cop_intercept,
        cop_oat_coeff=flo_params.cop_oat_coeff,
        cop_min=flo_params.cop_min,
        cop_min_oat_f=flo_params.cop_min_oat_f,
        constant_delta_t=flo_params.constant_delta_t,
    )
    
    true_initial_node = DNode(
        top_temp=flo_params.initial_top_temp_f,
        middle_temp=flo_params.initial_middle_temp_f,
        bottom_temp=flo_params.initial_bottom_temp_f,
        thermocline1=flo_params.initial_thermocline_1,
        thermocline2=flo_params.initial_thermocline_2,
        parameters=winter_oak_supergraph_params,
    )
    true_initial_states[i] = true_initial_node

    true_init_energy[i] = true_initial_node.energy
    true_init_node = DNodeVisualizer(true_initial_node, 'true_initial')
    init_node = DNodeVisualizer(g.initial_node, 'initial')
    expected_node = DNodeVisualizer(g.initial_node.next_node, 'expected')
    true_init_node.plot(save_as=f'plots/flo{i+1}_true_initial.png')
    init_node.plot(save_as=f'plots/flo{i+1}_initial.png')
    expected_node.plot(save_as=f'plots/flo{i+1}_expected.png')
    if i!=0:
        true_final_node = DNode(
            top_temp=flo_params.initial_top_temp_f,
            middle_temp=flo_params.initial_middle_temp_f,
            bottom_temp=flo_params.initial_bottom_temp_f,
            thermocline1=flo_params.initial_thermocline_1,
            thermocline2=flo_params.initial_thermocline_2,
            parameters=winter_oak_supergraph_params,
        )
        true_final_states[i-1] = true_final_node
        true_final_energy[i-1] = true_final_node.energy
        true_final_node = DNodeVisualizer(true_final_node, 'true_final')
        true_final_node.plot(save_as=f'plots/flo{i}_true_final.png')
        final_node = DNodeVisualizer(g.initial_node, 'final')
        final_node.plot(save_as=f'plots/flo{i}_final.png')

    del g, v, init_node, expected_node
    gc.collect()

heat_to_store_true = [round(final-init, 2) for final, init in zip(true_final_energy, true_init_energy)]

# Save to local pickle files
import pickle
with open("true_initial_states.pkl", "wb") as f:
    pickle.dump(true_initial_states, f)
with open("true_final_states.pkl", "wb") as f:
    pickle.dump(true_final_states, f)
with open("heat_to_store_true.pkl", "wb") as f:
    pickle.dump(heat_to_store_true, f)
with open("flo_params_messages.pkl", "wb") as f:
    pickle.dump(flo_params_messages, f)
# Out:
# Welcome to the FLO report generator!
#
# Generating report for oak from 2026-01-29 00:00:00-05:00 to 2026-01-31 07:00:00-05:00
#
# Adding message from hw1.isone.me.versant.keene.oak at 2026-01-28 23:57:48.756000-05:00
# Adding message from hw1.isone.me.versant.keene.oak at 2026-01-29 00:57:48.129000-05:00
# Adding message from hw1.isone.me.versant.keene.oak at 2026-01-29 01:57:47.554000-05:00
# Adding message from hw1.isone.me.versant.keene.oak at 2026-01-29 02:57:47.698000-05:00
# Adding message from hw1.isone.me.versant.keene.oak at 2026-01-29 03:57:47.093000-05:00
# Adding message from hw1.isone.me.versant.keene.oak at 2026-01-29 04:57:47.878000-05:00
# Adding message from hw1.isone.me.versant.keene.oak at 2026-01-29 05:57:17.486000-05:00
# Adding message from hw1.isone.me.versant.keene.oak at 2026-01-29 06:57:17.975000-05:00
# Adding message from hw1.isone.me.versant.keene.oak at 2026-01-29 07:57:17.945000-05:00
# Adding message from hw1.isone.me.versant.keene.oak at 2026-01-29 08:57:18.080000-05:00
# Adding message from hw1.isone.me.versant.keene.oak at 2026-01-29 09:57:14.021000-05:00
# Adding message from hw1.isone.me.versant.keene.oak at 2026-01-29 10:57:13.960000-05:00
# Adding message from hw1.isone.me.versant.keene.oak at 2026-01-29 11:57:13.999000-05:00
# Adding message from hw1.isone.me.versant.keene.oak at 2026-01-29 12:57:14.973000-05:00
# Adding message from hw1.isone.me.versant.keene.oak at 2026-01-29 13:57:15.099000-05:00
# Adding message from hw1.isone.me.versant.keene.oak at 2026-01-29 14:57:14.783000-05:00
# Adding message from hw1.isone.me.versant.keene.oak at 2026-01-29 15:57:15.327000-05:00
# Adding message from hw1.isone.me.versant.keene.oak at 2026-01-29 16:57:15.743000-05:00
# Adding message from hw1.isone.me.versant.keene.oak at 2026-01-29 17:57:15.515000-05:00
# Adding message from hw1.isone.me.versant.keene.oak at 2026-01-29 18:57:15.106000-05:00
# Adding message from hw1.isone.me.versant.keene.oak at 2026-01-29 19:57:15.160000-05:00
# Adding message from hw1.isone.me.versant.keene.oak at 2026-01-29 20:57:15.248000-05:00
# Adding message from hw1.isone.me.versant.keene.oak at 2026-01-29 21:57:14.630000-05:00
# Adding message from hw1.isone.me.versant.keene.oak at 2026-01-29 22:57:14.028000-05:00
# Adding message from hw1.isone.me.versant.keene.oak at 2026-01-29 23:57:13.773000-05:00
# Adding message from hw1.isone.me.versant.keene.oak at 2026-01-30 00:57:14.541000-05:00
# Adding message from hw1.isone.me.versant.keene.oak at 2026-01-30 01:57:14.058000-05:00
# Adding message from hw1.isone.me.versant.keene.oak at 2026-01-30 02:57:14.353000-05:00
# Adding message from hw1.isone.me.versant.keene.oak at 2026-01-30 03:57:14.569000-05:00
# Adding message from hw1.isone.me.versant.keene.oak at 2026-01-30 04:57:14.039000-05:00
# Adding message from hw1.isone.me.versant.keene.oak at 2026-01-30 05:57:14.260000-05:00
# Found 62 messages and 31 of them at minute 57
# 2026-01-31 13:19:10,472 [INFO] gridflo.flo: Launching flo for hw1.isone.me.versant.keene.oak.scada
# Found 24 hourly records for oak (hp_elec_in, hp_heat_out)
# 2026-01-31 13:19:10,830 [INFO] gridflo.flo: Loaded supergraph with 507 entries from /Users/thomas/.config/gridworks/gridflo/supergraph_25b9e6a4.json.gz
# 2026-01-31 13:19:11,934 [INFO] gridflo.flo: Built a graph with 48 layers of 6048 nodes each
# 2026-01-31 13:19:11,936 [INFO] gridflo.flo: Created nodes in 1.1 seconds
# 2026-01-31 13:19:14,621 [INFO] gridflo.flo: Created edges in 2.7 seconds
# 2026-01-31 13:19:14,905 [INFO] gridflo.flo: Solved Dijkstra in 0.1 seconds
# 2026-01-31 13:19:14,905 [INFO] gridflo.flo: Generating recommendation for hw1.isone.me.versant.keene.oak.scada...
# 2026-01-31 13:19:14,907 [INFO] gridflo.flo: Done (2 PQ pairs found).
# 2026-01-31 13:19:15,223 [INFO] gridflo.flo: Generating recommendation for hw1.isone.me.versant.keene.oak.scada...
# 2026-01-31 13:19:15,225 [INFO] gridflo.flo: Done (2 PQ pairs found).
# 2026-01-31 13:19:15,735 [INFO] gridflo.flo: Launching flo for hw1.isone.me.versant.keene.oak.scada
# 2026-01-31 13:19:16,055 [INFO] gridflo.flo: Loaded supergraph with 507 entries from /Users/thomas/.config/gridworks/gridflo/supergraph_25b9e6a4.json.gz
# 2026-01-31 13:19:17,083 [INFO] gridflo.flo: Built a graph with 48 layers of 6048 nodes each
# 2026-01-31 13:19:17,084 [INFO] gridflo.flo: Created nodes in 1.0 seconds
# 2026-01-31 13:19:19,865 [INFO] gridflo.flo: Created edges in 2.8 seconds
# 2026-01-31 13:19:20,178 [INFO] gridflo.flo: Solved Dijkstra in 0.1 seconds
# 2026-01-31 13:19:20,179 [INFO] gridflo.flo: Generating recommendation for hw1.isone.me.versant.keene.oak.scada...
# 2026-01-31 13:19:20,181 [INFO] gridflo.flo: Done (2 PQ pairs found).
# 2026-01-31 13:19:20,464 [INFO] gridflo.flo: Generating recommendation for hw1.isone.me.versant.keene.oak.scada...
# 2026-01-31 13:19:20,466 [INFO] gridflo.flo: Done (2 PQ pairs found).
# 2026-01-31 13:19:21,091 [INFO] gridflo.flo: Launching flo for hw1.isone.me.versant.keene.oak.scada
# 2026-01-31 13:19:21,426 [INFO] gridflo.flo: Loaded supergraph with 507 entries from /Users/thomas/.config/gridworks/gridflo/supergraph_25b9e6a4.json.gz
# 2026-01-31 13:19:22,505 [INFO] gridflo.flo: Built a graph with 48 layers of 6048 nodes each
# 2026-01-31 13:19:22,507 [INFO] gridflo.flo: Created nodes in 1.1 seconds
# 2026-01-31 13:19:25,223 [INFO] gridflo.flo: Created edges in 2.7 seconds
# 2026-01-31 13:19:25,526 [INFO] gridflo.flo: Solved Dijkstra in 0.1 seconds
# 2026-01-31 13:19:25,526 [INFO] gridflo.flo: Generating recommendation for hw1.isone.me.versant.keene.oak.scada...
# 2026-01-31 13:19:25,528 [INFO] gridflo.flo: Done (2 PQ pairs found).
# 2026-01-31 13:19:25,827 [INFO] gridflo.flo: Generating recommendation for hw1.isone.me.versant.keene.oak.scada...
# 2026-01-31 13:19:25,830 [INFO] gridflo.flo: Done (2 PQ pairs found).
# 2026-01-31 13:19:26,623 [INFO] gridflo.flo: Launching flo for hw1.isone.me.versant.keene.oak.scada
# 2026-01-31 13:19:26,936 [INFO] gridflo.flo: Loaded supergraph with 507 entries from /Users/thomas/.config/gridworks/gridflo/supergraph_25b9e6a4.json.gz
# 2026-01-31 13:19:27,926 [INFO] gridflo.flo: Built a graph with 48 layers of 6048 nodes each
# 2026-01-31 13:19:27,928 [INFO] gridflo.flo: Created nodes in 1.0 seconds
# 2026-01-31 13:19:30,712 [INFO] gridflo.flo: Created edges in 2.8 seconds
# 2026-01-31 13:19:31,007 [INFO] gridflo.flo: Solved Dijkstra in 0.1 seconds
# 2026-01-31 13:19:31,008 [INFO] gridflo.flo: Generating recommendation for hw1.isone.me.versant.keene.oak.scada...
# 2026-01-31 13:19:31,010 [INFO] gridflo.flo: Done (2 PQ pairs found).
# 2026-01-31 13:19:31,292 [INFO] gridflo.flo: Generating recommendation for hw1.isone.me.versant.keene.oak.scada...
# 2026-01-31 13:19:31,294 [INFO] gridflo.flo: Done (2 PQ pairs found).
# 2026-01-31 13:19:32,113 [INFO] gridflo.flo: Launching flo for hw1.isone.me.versant.keene.oak.scada
# 2026-01-31 13:19:32,421 [INFO] gridflo.flo: Loaded supergraph with 507 entries from /Users/thomas/.config/gridworks/gridflo/supergraph_25b9e6a4.json.gz
# 2026-01-31 13:19:33,474 [INFO] gridflo.flo: Built a graph with 48 layers of 6048 nodes each
# 2026-01-31 13:19:33,478 [INFO] gridflo.flo: Created nodes in 1.1 seconds
# 2026-01-31 13:19:36,192 [INFO] gridflo.flo: Created edges in 2.7 seconds
# 2026-01-31 13:19:36,493 [INFO] gridflo.flo: Solved Dijkstra in 0.1 seconds
# 2026-01-31 13:19:36,493 [INFO] gridflo.flo: Generating recommendation for hw1.isone.me.versant.keene.oak.scada...
# 2026-01-31 13:19:36,495 [INFO] gridflo.flo: Done (2 PQ pairs found).
# 2026-01-31 13:19:36,778 [INFO] gridflo.flo: Generating recommendation for hw1.isone.me.versant.keene.oak.scada...
# 2026-01-31 13:19:36,780 [INFO] gridflo.flo: Done (2 PQ pairs found).
# 2026-01-31 13:19:37,766 [INFO] gridflo.flo: Launching flo for hw1.isone.me.versant.keene.oak.scada
# 2026-01-31 13:19:38,089 [INFO] gridflo.flo: Loaded supergraph with 507 entries from /Users/thomas/.config/gridworks/gridflo/supergraph_25b9e6a4.json.gz
# 2026-01-31 13:19:39,173 [INFO] gridflo.flo: Built a graph with 48 layers of 6048 nodes each
# 2026-01-31 13:19:39,175 [INFO] gridflo.flo: Created nodes in 1.1 seconds
# 2026-01-31 13:19:41,906 [INFO] gridflo.flo: Created edges in 2.7 seconds
# 2026-01-31 13:19:42,231 [INFO] gridflo.flo: Solved Dijkstra in 0.1 seconds
# 2026-01-31 13:19:42,232 [INFO] gridflo.flo: Generating recommendation for hw1.isone.me.versant.keene.oak.scada...
# 2026-01-31 13:19:42,234 [INFO] gridflo.flo: Done (2 PQ pairs found).
# 2026-01-31 13:19:42,516 [INFO] gridflo.flo: Generating recommendation for hw1.isone.me.versant.keene.oak.scada...
# 2026-01-31 13:19:42,518 [INFO] gridflo.flo: Done (2 PQ pairs found).
# 2026-01-31 13:19:43,420 [INFO] gridflo.flo: Launching flo for hw1.isone.me.versant.keene.oak.scada
# 2026-01-31 13:19:43,734 [INFO] gridflo.flo: Loaded supergraph with 507 entries from /Users/thomas/.config/gridworks/gridflo/supergraph_25b9e6a4.json.gz
# 2026-01-31 13:19:44,712 [INFO] gridflo.flo: Built a graph with 48 layers of 6048 nodes each
# 2026-01-31 13:19:44,714 [INFO] gridflo.flo: Created nodes in 1.0 seconds
# 2026-01-31 13:19:47,642 [INFO] gridflo.flo: Created edges in 2.9 seconds
# 2026-01-31 13:19:47,956 [INFO] gridflo.flo: Solved Dijkstra in 0.1 seconds
# 2026-01-31 13:19:47,957 [INFO] gridflo.flo: Generating recommendation for hw1.isone.me.versant.keene.oak.scada...
# 2026-01-31 13:19:47,959 [INFO] gridflo.flo: Done (2 PQ pairs found).
# 2026-01-31 13:19:48,241 [INFO] gridflo.flo: Generating recommendation for hw1.isone.me.versant.keene.oak.scada...
# 2026-01-31 13:19:48,243 [INFO] gridflo.flo: Done (2 PQ pairs found).
# 2026-01-31 13:19:49,240 [INFO] gridflo.flo: Launching flo for hw1.isone.me.versant.keene.oak.scada
# 2026-01-31 13:19:49,560 [INFO] gridflo.flo: Loaded supergraph with 507 entries from /Users/thomas/.config/gridworks/gridflo/supergraph_25b9e6a4.json.gz
# 2026-01-31 13:19:50,579 [INFO] gridflo.flo: Built a graph with 48 layers of 6048 nodes each
# 2026-01-31 13:19:50,581 [INFO] gridflo.flo: Created nodes in 1.0 seconds
# 2026-01-31 13:19:53,292 [INFO] gridflo.flo: Created edges in 2.7 seconds
# 2026-01-31 13:19:53,614 [INFO] gridflo.flo: Solved Dijkstra in 0.1 seconds
# 2026-01-31 13:19:53,614 [INFO] gridflo.flo: Generating recommendation for hw1.isone.me.versant.keene.oak.scada...
# 2026-01-31 13:19:53,616 [INFO] gridflo.flo: Done (2 PQ pairs found).
# 2026-01-31 13:19:53,899 [INFO] gridflo.flo: Generating recommendation for hw1.isone.me.versant.keene.oak.scada...
# 2026-01-31 13:19:53,901 [INFO] gridflo.flo: Done (2 PQ pairs found).
# 2026-01-31 13:19:54,534 [INFO] gridflo.flo: Launching flo for hw1.isone.me.versant.keene.oak.scada
# 2026-01-31 13:19:54,845 [INFO] gridflo.flo: Loaded supergraph with 507 entries from /Users/thomas/.config/gridworks/gridflo/supergraph_25b9e6a4.json.gz
# 2026-01-31 13:19:55,893 [INFO] gridflo.flo: Built a graph with 48 layers of 6048 nodes each
# 2026-01-31 13:19:55,895 [INFO] gridflo.flo: Created nodes in 1.0 seconds
# 2026-01-31 13:19:58,681 [INFO] gridflo.flo: Created edges in 2.8 seconds
# 2026-01-31 13:19:59,009 [INFO] gridflo.flo: Solved Dijkstra in 0.1 seconds
# 2026-01-31 13:19:59,009 [INFO] gridflo.flo: Generating recommendation for hw1.isone.me.versant.keene.oak.scada...
# 2026-01-31 13:19:59,011 [INFO] gridflo.flo: Done (2 PQ pairs found).
# 2026-01-31 13:19:59,296 [INFO] gridflo.flo: Generating recommendation for hw1.isone.me.versant.keene.oak.scada...
# 2026-01-31 13:19:59,298 [INFO] gridflo.flo: Done (2 PQ pairs found).
# 2026-01-31 13:20:00,012 [INFO] gridflo.flo: Launching flo for hw1.isone.me.versant.keene.oak.scada
# 2026-01-31 13:20:00,336 [INFO] gridflo.flo: Loaded supergraph with 507 entries from /Users/thomas/.config/gridworks/gridflo/supergraph_25b9e6a4.json.gz
# 2026-01-31 13:20:01,425 [INFO] gridflo.flo: Built a graph with 48 layers of 6048 nodes each
# 2026-01-31 13:20:01,427 [INFO] gridflo.flo: Created nodes in 1.1 seconds
# 2026-01-31 13:20:04,236 [INFO] gridflo.flo: Created edges in 2.8 seconds
# 2026-01-31 13:20:04,578 [INFO] gridflo.flo: Solved Dijkstra in 0.1 seconds
# 2026-01-31 13:20:04,578 [INFO] gridflo.flo: Generating recommendation for hw1.isone.me.versant.keene.oak.scada...
# 2026-01-31 13:20:04,580 [INFO] gridflo.flo: Done (2 PQ pairs found).
# 2026-01-31 13:20:04,870 [INFO] gridflo.flo: Generating recommendation for hw1.isone.me.versant.keene.oak.scada...
# 2026-01-31 13:20:04,872 [INFO] gridflo.flo: Done (2 PQ pairs found).
# 2026-01-31 13:20:05,843 [INFO] gridflo.flo: Launching flo for hw1.isone.me.versant.keene.oak.scada
# 2026-01-31 13:20:06,161 [INFO] gridflo.flo: Loaded supergraph with 507 entries from /Users/thomas/.config/gridworks/gridflo/supergraph_25b9e6a4.json.gz
# 2026-01-31 13:20:07,143 [INFO] gridflo.flo: Built a graph with 48 layers of 6048 nodes each
# 2026-01-31 13:20:07,145 [INFO] gridflo.flo: Created nodes in 1.0 seconds
# 2026-01-31 13:20:10,049 [INFO] gridflo.flo: Created edges in 2.9 seconds
# 2026-01-31 13:20:10,394 [INFO] gridflo.flo: Solved Dijkstra in 0.1 seconds
# 2026-01-31 13:20:10,394 [INFO] gridflo.flo: Generating recommendation for hw1.isone.me.versant.keene.oak.scada...
# 2026-01-31 13:20:10,396 [INFO] gridflo.flo: Done (2 PQ pairs found).
# 2026-01-31 13:20:10,681 [INFO] gridflo.flo: Generating recommendation for hw1.isone.me.versant.keene.oak.scada...
# 2026-01-31 13:20:10,683 [INFO] gridflo.flo: Done (2 PQ pairs found).
# 2026-01-31 13:20:11,335 [INFO] gridflo.flo: Launching flo for hw1.isone.me.versant.keene.oak.scada
# 2026-01-31 13:20:11,654 [INFO] gridflo.flo: Loaded supergraph with 507 entries from /Users/thomas/.config/gridworks/gridflo/supergraph_25b9e6a4.json.gz
# 2026-01-31 13:20:12,623 [INFO] gridflo.flo: Built a graph with 48 layers of 6048 nodes each
# 2026-01-31 13:20:12,625 [INFO] gridflo.flo: Created nodes in 1.0 seconds
# 2026-01-31 13:20:15,522 [INFO] gridflo.flo: Created edges in 2.9 seconds
# 2026-01-31 13:20:15,885 [INFO] gridflo.flo: Solved Dijkstra in 0.1 seconds
# 2026-01-31 13:20:15,886 [INFO] gridflo.flo: Generating recommendation for hw1.isone.me.versant.keene.oak.scada...
# 2026-01-31 13:20:15,887 [INFO] gridflo.flo: Done (2 PQ pairs found).
# 2026-01-31 13:20:16,171 [INFO] gridflo.flo: Generating recommendation for hw1.isone.me.versant.keene.oak.scada...
# 2026-01-31 13:20:16,173 [INFO] gridflo.flo: Done (2 PQ pairs found).
# 2026-01-31 13:20:16,819 [INFO] gridflo.flo: Launching flo for hw1.isone.me.versant.keene.oak.scada
# 2026-01-31 13:20:17,144 [INFO] gridflo.flo: Loaded supergraph with 507 entries from /Users/thomas/.config/gridworks/gridflo/supergraph_25b9e6a4.json.gz
# 2026-01-31 13:20:18,138 [INFO] gridflo.flo: Built a graph with 48 layers of 6048 nodes each
# 2026-01-31 13:20:18,139 [INFO] gridflo.flo: Created nodes in 1.0 seconds
# 2026-01-31 13:20:20,964 [INFO] gridflo.flo: Created edges in 2.8 seconds
# 2026-01-31 13:20:21,321 [INFO] gridflo.flo: Solved Dijkstra in 0.1 seconds
# 2026-01-31 13:20:21,321 [INFO] gridflo.flo: Generating recommendation for hw1.isone.me.versant.keene.oak.scada...
# 2026-01-31 13:20:21,323 [INFO] gridflo.flo: Done (2 PQ pairs found).
# 2026-01-31 13:20:21,611 [INFO] gridflo.flo: Generating recommendation for hw1.isone.me.versant.keene.oak.scada...
# 2026-01-31 13:20:21,613 [INFO] gridflo.flo: Done (2 PQ pairs found).
# 2026-01-31 13:20:22,317 [INFO] gridflo.flo: Launching flo for hw1.isone.me.versant.keene.oak.scada
# 2026-01-31 13:20:22,631 [INFO] gridflo.flo: Loaded supergraph with 507 entries from /Users/thomas/.config/gridworks/gridflo/supergraph_25b9e6a4.json.gz
# 2026-01-31 13:20:23,651 [INFO] gridflo.flo: Built a graph with 48 layers of 6048 nodes each
# 2026-01-31 13:20:23,652 [INFO] gridflo.flo: Created nodes in 1.0 seconds
# 2026-01-31 13:20:26,522 [INFO] gridflo.flo: Created edges in 2.9 seconds
# 2026-01-31 13:20:26,920 [INFO] gridflo.flo: Solved Dijkstra in 0.1 seconds
# 2026-01-31 13:20:26,920 [INFO] gridflo.flo: Generating recommendation for hw1.isone.me.versant.keene.oak.scada...
# 2026-01-31 13:20:26,922 [INFO] gridflo.flo: Done (2 PQ pairs found).
# 2026-01-31 13:20:27,216 [INFO] gridflo.flo: Generating recommendation for hw1.isone.me.versant.keene.oak.scada...
# 2026-01-31 13:20:27,218 [INFO] gridflo.flo: Done (2 PQ pairs found).
# 2026-01-31 13:20:27,861 [INFO] gridflo.flo: Launching flo for hw1.isone.me.versant.keene.oak.scada
# 2026-01-31 13:20:28,181 [INFO] gridflo.flo: Loaded supergraph with 507 entries from /Users/thomas/.config/gridworks/gridflo/supergraph_25b9e6a4.json.gz
# 2026-01-31 13:20:29,275 [INFO] gridflo.flo: Built a graph with 48 layers of 6048 nodes each
# 2026-01-31 13:20:29,277 [INFO] gridflo.flo: Created nodes in 1.1 seconds
# 2026-01-31 13:20:32,196 [INFO] gridflo.flo: Created edges in 2.9 seconds
# 2026-01-31 13:20:32,562 [INFO] gridflo.flo: Solved Dijkstra in 0.1 seconds
# 2026-01-31 13:20:32,563 [INFO] gridflo.flo: Generating recommendation for hw1.isone.me.versant.keene.oak.scada...
# 2026-01-31 13:20:32,565 [INFO] gridflo.flo: Done (2 PQ pairs found).
# 2026-01-31 13:20:32,852 [INFO] gridflo.flo: Generating recommendation for hw1.isone.me.versant.keene.oak.scada...
# 2026-01-31 13:20:32,854 [INFO] gridflo.flo: Done (2 PQ pairs found).
# 2026-01-31 13:20:33,942 [INFO] gridflo.flo: Launching flo for hw1.isone.me.versant.keene.oak.scada
# 2026-01-31 13:20:34,264 [INFO] gridflo.flo: Loaded supergraph with 507 entries from /Users/thomas/.config/gridworks/gridflo/supergraph_25b9e6a4.json.gz
# 2026-01-31 13:20:35,408 [INFO] gridflo.flo: Built a graph with 48 layers of 6048 nodes each
# 2026-01-31 13:20:35,409 [INFO] gridflo.flo: Created nodes in 1.1 seconds
# 2026-01-31 13:20:38,428 [INFO] gridflo.flo: Created edges in 3.0 seconds
# 2026-01-31 13:20:38,814 [INFO] gridflo.flo: Solved Dijkstra in 0.1 seconds
# 2026-01-31 13:20:38,814 [INFO] gridflo.flo: Generating recommendation for hw1.isone.me.versant.keene.oak.scada...
# 2026-01-31 13:20:38,816 [INFO] gridflo.flo: Done (2 PQ pairs found).
# 2026-01-31 13:20:39,118 [INFO] gridflo.flo: Generating recommendation for hw1.isone.me.versant.keene.oak.scada...
# 2026-01-31 13:20:39,120 [INFO] gridflo.flo: Done (2 PQ pairs found).
# 2026-01-31 13:20:40,159 [INFO] gridflo.flo: Launching flo for hw1.isone.me.versant.keene.oak.scada
# 2026-01-31 13:20:40,477 [INFO] gridflo.flo: Loaded supergraph with 507 entries from /Users/thomas/.config/gridworks/gridflo/supergraph_25b9e6a4.json.gz
# 2026-01-31 13:20:41,592 [INFO] gridflo.flo: Built a graph with 48 layers of 6048 nodes each
# 2026-01-31 13:20:41,594 [INFO] gridflo.flo: Created nodes in 1.1 seconds
# 2026-01-31 13:20:44,710 [INFO] gridflo.flo: Created edges in 3.1 seconds
# 2026-01-31 13:20:45,121 [INFO] gridflo.flo: Solved Dijkstra in 0.1 seconds
# 2026-01-31 13:20:45,121 [INFO] gridflo.flo: Generating recommendation for hw1.isone.me.versant.keene.oak.scada...
# 2026-01-31 13:20:45,123 [INFO] gridflo.flo: Done (3 PQ pairs found).
# 2026-01-31 13:20:45,433 [INFO] gridflo.flo: Generating recommendation for hw1.isone.me.versant.keene.oak.scada...
# 2026-01-31 13:20:45,435 [INFO] gridflo.flo: Done (3 PQ pairs found).
# 2026-01-31 13:20:46,403 [INFO] gridflo.flo: Launching flo for hw1.isone.me.versant.keene.oak.scada
# 2026-01-31 13:20:46,725 [INFO] gridflo.flo: Loaded supergraph with 507 entries from /Users/thomas/.config/gridworks/gridflo/supergraph_25b9e6a4.json.gz
# 2026-01-31 13:20:47,839 [INFO] gridflo.flo: Built a graph with 48 layers of 6048 nodes each
# 2026-01-31 13:20:47,840 [INFO] gridflo.flo: Created nodes in 1.1 seconds
# 2026-01-31 13:20:50,615 [INFO] gridflo.flo: Created edges in 2.8 seconds
# 2026-01-31 13:20:51,050 [INFO] gridflo.flo: Solved Dijkstra in 0.1 seconds
# 2026-01-31 13:20:51,051 [INFO] gridflo.flo: Generating recommendation for hw1.isone.me.versant.keene.oak.scada...
# 2026-01-31 13:20:51,053 [INFO] gridflo.flo: Done (2 PQ pairs found).
# 2026-01-31 13:20:51,368 [INFO] gridflo.flo: Generating recommendation for hw1.isone.me.versant.keene.oak.scada...
# 2026-01-31 13:20:51,370 [INFO] gridflo.flo: Done (2 PQ pairs found).
# 2026-01-31 13:20:52,152 [INFO] gridflo.flo: Launching flo for hw1.isone.me.versant.keene.oak.scada
# 2026-01-31 13:20:52,477 [INFO] gridflo.flo: Loaded supergraph with 507 entries from /Users/thomas/.config/gridworks/gridflo/supergraph_25b9e6a4.json.gz
# 2026-01-31 13:20:53,406 [INFO] gridflo.flo: Built a graph with 48 layers of 6048 nodes each
# 2026-01-31 13:20:53,408 [INFO] gridflo.flo: Created nodes in 0.9 seconds
# 2026-01-31 13:20:56,330 [INFO] gridflo.flo: Created edges in 2.9 seconds
# 2026-01-31 13:20:56,719 [INFO] gridflo.flo: Solved Dijkstra in 0.1 seconds
# 2026-01-31 13:20:56,719 [INFO] gridflo.flo: Generating recommendation for hw1.isone.me.versant.keene.oak.scada...
# 2026-01-31 13:20:56,721 [INFO] gridflo.flo: Done (2 PQ pairs found).
# 2026-01-31 13:20:57,011 [INFO] gridflo.flo: Generating recommendation for hw1.isone.me.versant.keene.oak.scada...
# 2026-01-31 13:20:57,013 [INFO] gridflo.flo: Done (2 PQ pairs found).
# 2026-01-31 13:20:57,940 [INFO] gridflo.flo: Launching flo for hw1.isone.me.versant.keene.oak.scada
# 2026-01-31 13:20:58,262 [INFO] gridflo.flo: Loaded supergraph with 507 entries from /Users/thomas/.config/gridworks/gridflo/supergraph_25b9e6a4.json.gz
# 2026-01-31 13:20:59,190 [INFO] gridflo.flo: Built a graph with 48 layers of 6048 nodes each
# 2026-01-31 13:20:59,192 [INFO] gridflo.flo: Created nodes in 0.9 seconds
# 2026-01-31 13:21:02,110 [INFO] gridflo.flo: Created edges in 2.9 seconds
# 2026-01-31 13:21:02,500 [INFO] gridflo.flo: Solved Dijkstra in 0.1 seconds
# 2026-01-31 13:21:02,501 [INFO] gridflo.flo: Generating recommendation for hw1.isone.me.versant.keene.oak.scada...
# 2026-01-31 13:21:02,503 [INFO] gridflo.flo: Done (2 PQ pairs found).
# 2026-01-31 13:21:02,795 [INFO] gridflo.flo: Generating recommendation for hw1.isone.me.versant.keene.oak.scada...
# 2026-01-31 13:21:02,797 [INFO] gridflo.flo: Done (2 PQ pairs found).
# 2026-01-31 13:21:03,595 [INFO] gridflo.flo: Launching flo for hw1.isone.me.versant.keene.oak.scada
# 2026-01-31 13:21:03,910 [INFO] gridflo.flo: Loaded supergraph with 507 entries from /Users/thomas/.config/gridworks/gridflo/supergraph_25b9e6a4.json.gz
# 2026-01-31 13:21:04,859 [INFO] gridflo.flo: Built a graph with 48 layers of 6048 nodes each
# 2026-01-31 13:21:04,860 [INFO] gridflo.flo: Created nodes in 0.9 seconds
# 2026-01-31 13:21:07,792 [INFO] gridflo.flo: Created edges in 2.9 seconds
# 2026-01-31 13:21:08,210 [INFO] gridflo.flo: Solved Dijkstra in 0.1 seconds
# 2026-01-31 13:21:08,211 [INFO] gridflo.flo: Generating recommendation for hw1.isone.me.versant.keene.oak.scada...
# 2026-01-31 13:21:08,213 [INFO] gridflo.flo: Done (2 PQ pairs found).
# 2026-01-31 13:21:08,508 [INFO] gridflo.flo: Generating recommendation for hw1.isone.me.versant.keene.oak.scada...
# 2026-01-31 13:21:08,510 [INFO] gridflo.flo: Done (2 PQ pairs found).
# 2026-01-31 13:21:09,275 [INFO] gridflo.flo: Launching flo for hw1.isone.me.versant.keene.oak.scada
# 2026-01-31 13:21:09,592 [INFO] gridflo.flo: Loaded supergraph with 507 entries from /Users/thomas/.config/gridworks/gridflo/supergraph_25b9e6a4.json.gz
# 2026-01-31 13:21:10,548 [INFO] gridflo.flo: Built a graph with 48 layers of 6048 nodes each
# 2026-01-31 13:21:10,549 [INFO] gridflo.flo: Created nodes in 1.0 seconds
# 2026-01-31 13:21:13,565 [INFO] gridflo.flo: Created edges in 3.0 seconds
# 2026-01-31 13:21:14,009 [INFO] gridflo.flo: Solved Dijkstra in 0.1 seconds
# 2026-01-31 13:21:14,010 [INFO] gridflo.flo: Generating recommendation for hw1.isone.me.versant.keene.oak.scada...
# 2026-01-31 13:21:14,012 [INFO] gridflo.flo: Done (2 PQ pairs found).
# 2026-01-31 13:21:14,329 [INFO] gridflo.flo: Generating recommendation for hw1.isone.me.versant.keene.oak.scada...
# 2026-01-31 13:21:14,332 [INFO] gridflo.flo: Done (2 PQ pairs found).
# 2026-01-31 13:21:15,114 [INFO] gridflo.flo: Launching flo for hw1.isone.me.versant.keene.oak.scada
# 2026-01-31 13:21:15,438 [INFO] gridflo.flo: Loaded supergraph with 507 entries from /Users/thomas/.config/gridworks/gridflo/supergraph_25b9e6a4.json.gz
# 2026-01-31 13:21:16,409 [INFO] gridflo.flo: Built a graph with 48 layers of 6048 nodes each
# 2026-01-31 13:21:16,410 [INFO] gridflo.flo: Created nodes in 1.0 seconds
# 2026-01-31 13:21:19,401 [INFO] gridflo.flo: Created edges in 3.0 seconds
# 2026-01-31 13:21:19,813 [INFO] gridflo.flo: Solved Dijkstra in 0.1 seconds
# 2026-01-31 13:21:19,813 [INFO] gridflo.flo: Generating recommendation for hw1.isone.me.versant.keene.oak.scada...
# 2026-01-31 13:21:19,815 [INFO] gridflo.flo: Done (2 PQ pairs found).
# 2026-01-31 13:21:20,112 [INFO] gridflo.flo: Generating recommendation for hw1.isone.me.versant.keene.oak.scada...
# 2026-01-31 13:21:20,114 [INFO] gridflo.flo: Done (2 PQ pairs found).
# 2026-01-31 13:21:20,808 [INFO] gridflo.flo: Launching flo for hw1.isone.me.versant.keene.oak.scada
# 2026-01-31 13:21:21,151 [INFO] gridflo.flo: Loaded supergraph with 507 entries from /Users/thomas/.config/gridworks/gridflo/supergraph_25b9e6a4.json.gz
# 2026-01-31 13:21:22,188 [INFO] gridflo.flo: Built a graph with 48 layers of 6048 nodes each
# 2026-01-31 13:21:22,189 [INFO] gridflo.flo: Created nodes in 1.0 seconds
# 2026-01-31 13:21:25,273 [INFO] gridflo.flo: Created edges in 3.1 seconds
# 2026-01-31 13:21:25,692 [INFO] gridflo.flo: Solved Dijkstra in 0.1 seconds
# 2026-01-31 13:21:25,693 [INFO] gridflo.flo: Generating recommendation for hw1.isone.me.versant.keene.oak.scada...
# 2026-01-31 13:21:25,694 [INFO] gridflo.flo: Done (2 PQ pairs found).
# 2026-01-31 13:21:25,990 [INFO] gridflo.flo: Generating recommendation for hw1.isone.me.versant.keene.oak.scada...
# 2026-01-31 13:21:25,992 [INFO] gridflo.flo: Done (2 PQ pairs found).
# 2026-01-31 13:21:26,721 [INFO] gridflo.flo: Launching flo for hw1.isone.me.versant.keene.oak.scada
# 2026-01-31 13:21:27,044 [INFO] gridflo.flo: Loaded supergraph with 507 entries from /Users/thomas/.config/gridworks/gridflo/supergraph_25b9e6a4.json.gz
# 2026-01-31 13:21:28,037 [INFO] gridflo.flo: Built a graph with 48 layers of 6048 nodes each
# 2026-01-31 13:21:28,039 [INFO] gridflo.flo: Created nodes in 1.0 seconds
# 2026-01-31 13:21:31,165 [INFO] gridflo.flo: Created edges in 3.1 seconds
# 2026-01-31 13:21:31,601 [INFO] gridflo.flo: Solved Dijkstra in 0.1 seconds
# 2026-01-31 13:21:31,601 [INFO] gridflo.flo: Generating recommendation for hw1.isone.me.versant.keene.oak.scada...
# 2026-01-31 13:21:31,603 [INFO] gridflo.flo: Done (3 PQ pairs found).
# 2026-01-31 13:21:31,905 [INFO] gridflo.flo: Generating recommendation for hw1.isone.me.versant.keene.oak.scada...
# 2026-01-31 13:21:31,907 [INFO] gridflo.flo: Done (3 PQ pairs found).
# 2026-01-31 13:21:32,562 [INFO] gridflo.flo: Launching flo for hw1.isone.me.versant.keene.oak.scada
# 2026-01-31 13:21:32,885 [INFO] gridflo.flo: Loaded supergraph with 507 entries from /Users/thomas/.config/gridworks/gridflo/supergraph_25b9e6a4.json.gz
# 2026-01-31 13:21:33,907 [INFO] gridflo.flo: Built a graph with 48 layers of 6048 nodes each
# 2026-01-31 13:21:33,909 [INFO] gridflo.flo: Created nodes in 1.0 seconds
# 2026-01-31 13:21:36,993 [INFO] gridflo.flo: Created edges in 3.1 seconds
# 2026-01-31 13:21:37,445 [INFO] gridflo.flo: Solved Dijkstra in 0.1 seconds
# 2026-01-31 13:21:37,446 [INFO] gridflo.flo: Generating recommendation for hw1.isone.me.versant.keene.oak.scada...
# 2026-01-31 13:21:37,448 [INFO] gridflo.flo: Done (2 PQ pairs found).
# 2026-01-31 13:21:37,746 [INFO] gridflo.flo: Generating recommendation for hw1.isone.me.versant.keene.oak.scada...
# 2026-01-31 13:21:37,748 [INFO] gridflo.flo: Done (2 PQ pairs found).
# 2026-01-31 13:21:38,420 [INFO] gridflo.flo: Launching flo for hw1.isone.me.versant.keene.oak.scada
# 2026-01-31 13:21:38,745 [INFO] gridflo.flo: Loaded supergraph with 507 entries from /Users/thomas/.config/gridworks/gridflo/supergraph_25b9e6a4.json.gz
# 2026-01-31 13:21:39,780 [INFO] gridflo.flo: Built a graph with 48 layers of 6048 nodes each
# 2026-01-31 13:21:39,782 [INFO] gridflo.flo: Created nodes in 1.0 seconds
# 2026-01-31 13:21:42,556 [INFO] gridflo.flo: Created edges in 2.8 seconds
# 2026-01-31 13:21:42,986 [INFO] gridflo.flo: Solved Dijkstra in 0.1 seconds
# 2026-01-31 13:21:42,986 [INFO] gridflo.flo: Generating recommendation for hw1.isone.me.versant.keene.oak.scada...
# 2026-01-31 13:21:42,988 [INFO] gridflo.flo: Done (2 PQ pairs found).
# 2026-01-31 13:21:43,284 [INFO] gridflo.flo: Generating recommendation for hw1.isone.me.versant.keene.oak.scada...
# 2026-01-31 13:21:43,286 [INFO] gridflo.flo: Done (2 PQ pairs found).
# 2026-01-31 13:21:44,113 [INFO] gridflo.flo: Launching flo for hw1.isone.me.versant.keene.oak.scada
# 2026-01-31 13:21:44,438 [INFO] gridflo.flo: Loaded supergraph with 507 entries from /Users/thomas/.config/gridworks/gridflo/supergraph_25b9e6a4.json.gz
# 2026-01-31 13:21:45,470 [INFO] gridflo.flo: Built a graph with 48 layers of 6048 nodes each
# 2026-01-31 13:21:45,471 [INFO] gridflo.flo: Created nodes in 1.0 seconds
# 2026-01-31 13:21:48,297 [INFO] gridflo.flo: Created edges in 2.8 seconds
# 2026-01-31 13:21:48,766 [INFO] gridflo.flo: Solved Dijkstra in 0.1 seconds
# 2026-01-31 13:21:48,767 [INFO] gridflo.flo: Generating recommendation for hw1.isone.me.versant.keene.oak.scada...
# 2026-01-31 13:21:48,769 [INFO] gridflo.flo: Done (2 PQ pairs found).
# 2026-01-31 13:21:49,081 [INFO] gridflo.flo: Generating recommendation for hw1.isone.me.versant.keene.oak.scada...
# 2026-01-31 13:21:49,083 [INFO] gridflo.flo: Done (2 PQ pairs found).
# 2026-01-31 13:21:50,018 [INFO] gridflo.flo: Launching flo for hw1.isone.me.versant.keene.oak.scada
# 2026-01-31 13:21:50,342 [INFO] gridflo.flo: Loaded supergraph with 507 entries from /Users/thomas/.config/gridworks/gridflo/supergraph_25b9e6a4.json.gz
# 2026-01-31 13:21:51,409 [INFO] gridflo.flo: Built a graph with 48 layers of 6048 nodes each
# 2026-01-31 13:21:51,410 [INFO] gridflo.flo: Created nodes in 1.1 seconds
# 2026-01-31 13:21:54,297 [INFO] gridflo.flo: Created edges in 2.9 seconds
# 2026-01-31 13:21:54,747 [INFO] gridflo.flo: Solved Dijkstra in 0.1 seconds
# 2026-01-31 13:21:54,748 [INFO] gridflo.flo: Generating recommendation for hw1.isone.me.versant.keene.oak.scada...
# 2026-01-31 13:21:54,749 [INFO] gridflo.flo: Done (2 PQ pairs found).
# 2026-01-31 13:21:55,042 [INFO] gridflo.flo: Generating recommendation for hw1.isone.me.versant.keene.oak.scada...
# 2026-01-31 13:21:55,043 [INFO] gridflo.flo: Done (2 PQ pairs found).
# 2026-01-31 13:21:55,781 [INFO] gridflo.flo: Launching flo for hw1.isone.me.versant.keene.oak.scada
# 2026-01-31 13:21:56,111 [INFO] gridflo.flo: Loaded supergraph with 507 entries from /Users/thomas/.config/gridworks/gridflo/supergraph_25b9e6a4.json.gz
# 2026-01-31 13:21:57,197 [INFO] gridflo.flo: Built a graph with 48 layers of 6048 nodes each
# 2026-01-31 13:21:57,199 [INFO] gridflo.flo: Created nodes in 1.1 seconds
# 2026-01-31 13:22:00,060 [INFO] gridflo.flo: Created edges in 2.9 seconds
# 2026-01-31 13:22:00,505 [INFO] gridflo.flo: Solved Dijkstra in 0.1 seconds
# 2026-01-31 13:22:00,506 [INFO] gridflo.flo: Generating recommendation for hw1.isone.me.versant.keene.oak.scada...
# 2026-01-31 13:22:00,508 [INFO] gridflo.flo: Done (2 PQ pairs found).
# 2026-01-31 13:22:00,808 [INFO] gridflo.flo: Generating recommendation for hw1.isone.me.versant.keene.oak.scada...
# 2026-01-31 13:22:00,810 [INFO] gridflo.flo: Done (2 PQ pairs found).
# 2026-01-31 13:22:01,458 [INFO] gridflo.flo: Launching flo for hw1.isone.me.versant.keene.oak.scada
# 2026-01-31 13:22:01,778 [INFO] gridflo.flo: Loaded supergraph with 507 entries from /Users/thomas/.config/gridworks/gridflo/supergraph_25b9e6a4.json.gz
# 2026-01-31 13:22:02,868 [INFO] gridflo.flo: Built a graph with 48 layers of 6048 nodes each
# 2026-01-31 13:22:02,870 [INFO] gridflo.flo: Created nodes in 1.1 seconds
# 2026-01-31 13:22:05,737 [INFO] gridflo.flo: Created edges in 2.9 seconds
# 2026-01-31 13:22:06,191 [INFO] gridflo.flo: Solved Dijkstra in 0.1 seconds
# 2026-01-31 13:22:06,191 [INFO] gridflo.flo: Generating recommendation for hw1.isone.me.versant.keene.oak.scada...
# 2026-01-31 13:22:06,193 [INFO] gridflo.flo: Done (2 PQ pairs found).
# 2026-01-31 13:22:06,501 [INFO] gridflo.flo: Generating recommendation for hw1.isone.me.versant.keene.oak.scada...
# 2026-01-31 13:22:06,503 [INFO] gridflo.flo: Done (2 PQ pairs found).
